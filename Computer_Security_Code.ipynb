# %%
pip install phe
# Out:
# Requirement already satisfied: phe in /usr/local/lib/python3.10/dist-packages (1.5.0)

# %%
import pandas as pd
from phe import paillier
from collections import defaultdict
import multiprocessing

dataframe = pd.read_csv(r'/content/primary-2015-election-summary.csv')
sorted_df = dataframe.sort_values(by='Contest Name')


sorted_df.to_csv('sorted_contests.csv', index=False)

# %%
sorted_df
# Out:
#       Votes  Prec. Count Party Dist. Type  Dist. Code          Contest Name  \
# 2103    280            6   REP        NaN         NaN      Auditor BELLEVUE
# 578      29            6   DEM        NaN         NaN      Auditor BELLEVUE
# 2104      5            6   REP        NaN         NaN      Auditor BELLEVUE
# 579      95            2   DEM        NaN         NaN     Auditor EAST DEER
# 602      85            2   DEM        NaN         NaN     Auditor EAST DEER
# ...     ...          ...   ...        ...         ...                   ...
# 577       9           38   DEM        NaN         NaN  Treasurer MT LEBANON
# 576    2005           38   DEM        NaN         NaN  Treasurer MT LEBANON
# 2102     35           38   REP        NaN         NaN  Treasurer MT LEBANON
# 2782   1166           17   NaN        MUN       228.0  Wilkinsburg Question
# 2783    768           17   NaN        MUN       228.0  Wilkinsburg Question
#
#       Cand. Num              Cand. Name  Vote for  Ref
# 2103          1         Lenora Z. Bauer         1  NaN
# 578           1                WRITE-IN         1  NaN
# 2104          2                WRITE-IN         1  NaN
# 579           1       Jennifer L. Savka         1  NaN
# 602           1  Timothy Daniel McKenna         1  NaN
# ...         ...                     ...       ...  ...
# 577           2                WRITE-IN         1  NaN
# 576           1            Joseph Senko         1  NaN
# 2102          1                WRITE-IN         1  NaN
# 2782          1                     Yes         1    Y
# 2783          2                      No         1    Y
#
# [2784 rows x 10 columns]

# %%
import pandas as pd
from phe import paillier
from collections import defaultdict
import multiprocessing

# Generate multiple Paillier key pairs with varying sizes
key_sizes = [1024, 2048, 3072]
key_pairs = [paillier.generate_paillier_keypair(n_length=size) for size in key_sizes]

df = sorted_df

def encrypt_votes_with_variations(votes, key_pairs):
    encrypted_votes = []
    for vote in votes:

        encrypted_vote = key_pairs[0][0].encrypt(vote)

        intermediate_value = key_pairs[0][1].decrypt(encrypted_vote)
        encrypted_intermediate = key_pairs[1][0].encrypt(intermediate_value)

        final_value = key_pairs[1][1].decrypt(encrypted_intermediate)
        final_encrypted_vote = key_pairs[2][0].encrypt(final_value)
        encrypted_votes.append(final_encrypted_vote)
    return encrypted_votes


def sum_encrypted_votes(encrypted_votes):
    return sum(encrypted_votes, start=key_pairs[2][0].encrypt(0))


def chunk_data(data, chunk_size):
    for i in range(0, len(data), chunk_size):
        yield data[i:i + chunk_size]


def parallel_encrypt_votes(votes_chunks, key_pairs):
    with multiprocessing.Pool() as pool:
        encrypted_votes_chunks = pool.starmap(encrypt_votes_with_variations, [(chunk, key_pairs) for chunk in votes_chunks])
    return encrypted_votes_chunks


def parallel_sum_encrypted_votes(encrypted_votes_chunks):
    with multiprocessing.Pool() as pool:
        encrypted_totals_chunks = pool.map(sum_encrypted_votes, encrypted_votes_chunks)
    return encrypted_totals_chunks


results = defaultdict(lambda: defaultdict(list))


grouped = df.groupby('Contest Name')

for contest_name, group in grouped:
    candidates = group['Cand. Num'].unique()
    candidate_names = {row['Cand. Num']: row['Cand. Name'] for idx, row in group.iterrows()}


    votes = group['Vote for'].tolist()


    votes_chunks = list(chunk_data(votes, 1000))
    encrypted_votes_chunks = parallel_encrypt_votes(votes_chunks, key_pairs)


    total_encrypted_votes = parallel_sum_encrypted_votes(encrypted_votes_chunks)


    total_encrypted = sum(total_encrypted_votes, start=key_pairs[2][0].encrypt(0))


    decrypted_total_votes = key_pairs[2][1].decrypt(total_encrypted)

    candidate_vote_counts = defaultdict(int)
    for encrypted_vote_chunk in encrypted_votes_chunks:
        for vote in encrypted_vote_chunk:
            decrypted_round3 = key_pairs[2][1].decrypt(vote)
            encrypted_intermediate = key_pairs[1][0].encrypt(decrypted_round3)
            decrypted_round2 = key_pairs[1][1].decrypt(encrypted_intermediate)
            encrypted_original = key_pairs[0][0].encrypt(decrypted_round2)
            decrypted_original = key_pairs[0][1].decrypt(encrypted_original)
            candidate_vote_counts[decrypted_original] += 1


    for candidate in candidates:
        results[contest_name][candidate_names[candidate]].append(candidate_vote_counts[candidate])


winners = {}
for contest_name, candidates in results.items():
    winner = max(candidates.items(), key=lambda item: item[1][0])
    winners[contest_name] = winner


for contest_name, (candidate_name, votes) in winners.items():
    print(f"The winner of the {contest_name} contest is {candidate_name} with {votes[0]} votes.")


for contest_name, candidates in results.items():
    for candidate, votes in candidates.items():
        encrypted_total_again = key_pairs[2][0].encrypt(votes[0])
        print(f"Encrypted total votes for {candidate} in {contest_name}: {encrypted_total_again.ciphertext()}")
# Out:
# The winner of the Auditor BELLEVUE contest is WRITE-IN with 3 votes.
# The winner of the Auditor EAST DEER contest is WRITE-IN with 9 votes.
# The winner of the Auditor ETNA contest is WRITE-IN with 0 votes.
# The winner of the Auditor FAWN contest is WRITE-IN with 6 votes.
# The winner of the Auditor FINDLAY contest is WRITE-IN with 2 votes.
# The winner of the Auditor FORWARD contest is WRITE-IN with 6 votes.
# The winner of the Auditor FRAZER contest is WRITE-IN with 2 votes.
# The winner of the Auditor GLENFIELD contest is WRITE-IN with 6 votes.
# The winner of the Auditor HARMAR contest is WRITE-IN with 2 votes.
# The winner of the Auditor INDIANA contest is WRITE-IN with 4 votes.
# The winner of the Auditor KILBUCK contest is WRITE-IN with 2 votes.
# The winner of the Auditor MARSHALL contest is WRITE-IN with 2 votes.
# The winner of the Auditor MOON contest is WRITE-IN with 2 votes.
# The winner of the Auditor MT OLIVER contest is WRITE-IN with 5 votes.
# The winner of the Auditor NORTH FAYETTE contest is WRITE-IN with 2 votes.
# The winner of the Auditor OHARA contest is WRITE-IN with 4 votes.
# The winner of the Auditor SOUTH PARK contest is WRITE-IN with 6 votes.
# The winner of the Auditor TURTLE CREEK contest is WRITE-IN with 3 votes.
# The winner of the Auditor WEST DEER contest is WRITE-IN with 4 votes.
# The winner of the Auditor WEST ELIZABETH contest is WRITE-IN with 4 votes.
# The winner of the Bellevue Question contest is Yes with 2 votes.
# The winner of the Commissioner ALEPPO contest is Arthur C. Williams with 4 votes.
# The winner of the Commissioner At-Large CRESCENT contest is Jeffrey T. Gagat with 4 votes.
# The winner of the Commissioner At-Large EAST DEER contest is John Nwranski with 5 votes.
# The winner of the Commissioner At-Large NEVILLE contest is WRITE-IN with 3 votes.
# The winner of the Commissioner At-Large RESERVE contest is Daniel G. Giebel with 4 votes.
# The winner of the Commissioner At-Large UPPER ST CLAIR contest is WRITE-IN with 2 votes.
# The winner of the Commissioner At-Large WILKINS contest is Mark E. Wells with 4 votes.
# The winner of the Commissioner BALDWIN TOWNSHIP contest is WRITE-IN with 6 votes.
# The winner of the Commissioner COLLIER contest is Wilson Durisko with 4 votes.
# The winner of the Commissioner CRESCENT WARD 1 contest is Brittany Fortuna with 4 votes.
# The winner of the Commissioner CRESCENT WARD 2 contest is Christina Komen with 4 votes.
# The winner of the Commissioner EAST DEER WARD 1 contest is WRITE-IN with 3 votes.
# The winner of the Commissioner ELIZABETH TOWNSHIP WARD 1 contest is George Dukic with 4 votes.
# The winner of the Commissioner ELIZABETH TOWNSHIP WARD 3 contest is Claire M. Bryce with 5 votes.
# The winner of the Commissioner ELIZABETH TOWNSHIP WARD 5 contest is WRITE-IN with 4 votes.
# The winner of the Commissioner ELIZABETH TOWNSHIP WARD 7 contest is WRITE-IN with 0 votes.
# The winner of the Commissioner HARRISON WARD 1 contest is Charles Dizard with 4 votes.
# The winner of the Commissioner HARRISON WARD 3 contest is WRITE-IN with 3 votes.
# The winner of the Commissioner HARRISON WARD 5 contest is WRITE-IN with 3 votes.
# The winner of the Commissioner KENNEDY contest is Mitch Galiyas with 4 votes.
# The winner of the Commissioner LEET contest is Jeff Besong with 6 votes.
# The winner of the Commissioner MT LEBANON WARD 1 contest is John Bendel with 4 votes.
# The winner of the Commissioner MT LEBANON WARD 3 contest is Andrew Reinhart with 4 votes.
# The winner of the Commissioner MT LEBANON WARD 5 contest is William L. Hoon with 4 votes.
# The winner of the Commissioner NEVILLE WARD 1 contest is Allen Whitaker with 3 votes.
# The winner of the Commissioner NEVILLE WARD 3 contest is WRITE-IN with 2 votes.
# The winner of the Commissioner NORTH VERSAILLES WARD 1 contest is George S. Thompson with 0 votes.
# The winner of the Commissioner NORTH VERSAILLES WARD 3 contest is Allen R. Wagner with 4 votes.
# The winner of the Commissioner NORTH VERSAILLES WARD 5 contest is Russell Saula with 3 votes.
# The winner of the Commissioner NORTH VERSAILLES WARD 7 contest is Frank J. Bivins with 3 votes.
# The winner of the Commissioner RESERVE WARD 1 contest is Gary M. Killmeyer with 3 votes.
# The winner of the Commissioner RESERVE WARD 3 contest is John Kaib with 3 votes.
# The winner of the Commissioner ROBINSON contest is John Earl with 6 votes.
# The winner of the Commissioner ROSS WARD 1 contest is Daniel L. DeMarco with 3 votes.
# The winner of the Commissioner ROSS WARD 3 contest is Richard E. Avon, Jr. with 4 votes.
# The winner of the Commissioner ROSS WARD 5 contest is WRITE-IN with 0 votes.
# The winner of the Commissioner ROSS WARD 7 contest is WRITE-IN with 4 votes.
# The winner of the Commissioner ROSS WARD 9 contest is Jack Betkowski with 4 votes.
# The winner of the Commissioner SCOTT WARD 1 contest is WRITE-IN with 3 votes.
# The winner of the Commissioner SCOTT WARD 3 contest is WRITE-IN with 3 votes.
# The winner of the Commissioner SCOTT WARD 5 contest is WRITE-IN with 0 votes.
# The winner of the Commissioner SCOTT WARD 7 contest is WRITE-IN with 0 votes.
# The winner of the Commissioner SCOTT WARD 9 contest is WRITE-IN with 3 votes.
# The winner of the Commissioner SHALER WARD 1 contest is Wayne R. Skelley with 4 votes.
# The winner of the Commissioner SHALER WARD 3 contest is David W. Shutter with 3 votes.
# The winner of the Commissioner SHALER WARD 5 contest is Susan H. Fisher with 3 votes.
# The winner of the Commissioner SHALER WARD 7 contest is WRITE-IN with 3 votes.
# The winner of the Commissioner SOUTH FAYETTE contest is Frederick M. Cardillo with 15 votes.
# The winner of the Commissioner SOUTH VERSAILLES contest is WRITE-IN with 4 votes.
# The winner of the Commissioner SPRINGDALE TOWNSHIP contest is James R. Biery with 8 votes.
# The winner of the Commissioner STOWE WARD 1 contest is WRITE-IN with 3 votes.
# The winner of the Commissioner STOWE WARD 3 contest is Cheryl McDermott with 3 votes.
# The winner of the Commissioner STOWE WARD 5 contest is Kelly Ann Cropper Hall with 4 votes.
# The winner of the Commissioner STOWE WARD 7 contest is Glenn E. Putas with 4 votes.
# The winner of the Commissioner STOWE WARD 9 contest is William H. Hoffman, Jr. with 3 votes.
# The winner of the Commissioner UPPER ST CLAIR WARD 1 contest is Nicholas J. Seitanakis with 3 votes.
# The winner of the Commissioner UPPER ST CLAIR WARD 3 contest is Bob Orchowski with 3 votes.
# The winner of the Commissioner UPPER ST CLAIR WARD 5 contest is Louis M. Oliverio with 3 votes.
# The winner of the Commissioner WILKINS WARD 1 contest is Michelle Criner with 4 votes.
# The winner of the Constable ALEPPO contest is WRITE-IN with 0 votes.
# The winner of the Constable ASPINWALL contest is WRITE-IN with 2 votes.
# The winner of the Constable AVALON WARD 1 contest is WRITE-IN with 2 votes.
# The winner of the Constable AVALON WARD 2 contest is WRITE-IN with 2 votes.
# The winner of the Constable AVALON WARD 3 contest is WRITE-IN with 2 votes.
# The winner of the Constable BALDWIN BOROUGH contest is James D. Hagan with 3 votes.
# The winner of the Constable BALDWIN TOWNSHIP contest is WRITE-IN with 0 votes.
# The winner of the Constable BELL ACRES contest is Robert A. Marek with 3 votes.
# The winner of the Constable BELLEVUE WARD 1 contest is WRITE-IN with 0 votes.
# The winner of the Constable BELLEVUE WARD 2 contest is WRITE-IN with 2 votes.
# The winner of the Constable BELLEVUE WARD 3 contest is WRITE-IN with 2 votes.
# The winner of the Constable BEN AVON contest is Richard L. White with 3 votes.
# The winner of the Constable BEN AVON HEIGHTS contest is WRITE-IN with 2 votes.
# The winner of the Constable BETHEL PARK WARD 1 contest is WRITE-IN with 2 votes.
# The winner of the Constable BETHEL PARK WARD 2 contest is WRITE-IN with 3 votes.
# The winner of the Constable BETHEL PARK WARD 3 contest is WRITE-IN with 2 votes.
# The winner of the Constable BETHEL PARK WARD 4 contest is WRITE-IN with 2 votes.
# The winner of the Constable BETHEL PARK WARD 5 contest is WRITE-IN with 3 votes.
# The winner of the Constable BETHEL PARK WARD 6 contest is WRITE-IN with 2 votes.
# The winner of the Constable BETHEL PARK WARD 7 contest is Matthew Ryan Verghies with 3 votes.
# The winner of the Constable BETHEL PARK WARD 8 contest is WRITE-IN with 2 votes.
# The winner of the Constable BETHEL PARK WARD 9 contest is WRITE-IN with 2 votes.
# The winner of the Constable BLAWNOX contest is Charles P. Stipetich, Jr. with 3 votes.
# The winner of the Constable BRACKENRIDGE WARD 1 contest is WRITE-IN with 2 votes.
# The winner of the Constable BRACKENRIDGE WARD 2 contest is WRITE-IN with 3 votes.
# The winner of the Constable BRACKENRIDGE WARD 3 contest is WRITE-IN with 2 votes.
# The winner of the Constable BRADDOCK HILLS contest is WRITE-IN with 3 votes.
# The winner of the Constable BRADDOCK WARD 1 contest is WRITE-IN with 2 votes.
# The winner of the Constable BRADDOCK WARD 2 contest is WRITE-IN with 3 votes.
# The winner of the Constable BRADDOCK WARD 3 contest is WRITE-IN with 2 votes.
# The winner of the Constable BRADFORD WOODS contest is WRITE-IN with 2 votes.
# The winner of the Constable BRENTWOOD contest is WRITE-IN with 3 votes.
# The winner of the Constable BRIDGEVILLE contest is Walter L. Johns with 3 votes.
# The winner of the Constable CARNEGIE WARD 1 contest is William Gardner with 3 votes.
# The winner of the Constable CARNEGIE WARD 2 contest is Mark Bassano with 3 votes.
# The winner of the Constable CASTLE SHANNON contest is WRITE-IN with 2 votes.
# The winner of the Constable CHALFANT contest is William C. Fisher with 3 votes.
# The winner of the Constable CHESWICK contest is Richard K. Franks with 3 votes.
# The winner of the Constable CHURCHILL contest is WRITE-IN with 2 votes.
# The winner of the Constable CLAIRTON WARD 1 contest is WRITE-IN with 3 votes.
# The winner of the Constable CLAIRTON WARD 2 contest is WRITE-IN with 2 votes.
# The winner of the Constable CLAIRTON WARD 3 contest is WRITE-IN with 2 votes.
# The winner of the Constable CLAIRTON WARD 4 contest is WRITE-IN with 0 votes.
# The winner of the Constable COLLIER contest is WRITE-IN with 0 votes.
# The winner of the Constable CORAOPOLIS WARD 1 contest is WRITE-IN with 2 votes.
# The winner of the Constable CORAOPOLIS WARD 2 contest is John F. Vith, Jr. with 3 votes.
# The winner of the Constable CORAOPOLIS WARD 3 contest is Harry J. Buntin with 3 votes.
# The winner of the Constable CORAOPOLIS WARD 4 contest is WRITE-IN with 3 votes.
# The winner of the Constable CRAFTON contest is James Bragano with 4 votes.
# The winner of the Constable CRESCENT contest is WRITE-IN with 0 votes.
# The winner of the Constable DORMONT contest is Shawn Reick with 3 votes.
# The winner of the Constable DRAVOSBURG contest is Paul I. Eagle with 3 votes.
# The winner of the Constable DUQUESNE WARD 1 contest is WRITE-IN with 2 votes.
# The winner of the Constable DUQUESNE WARD 2 contest is Frank M. Cobb with 0 votes.
# The winner of the Constable DUQUESNE WARD 3 contest is WRITE-IN with 0 votes.
# The winner of the Constable EAST DEER contest is James H. Oconis with 4 votes.
# The winner of the Constable EAST MCKEESPORT contest is Justin Firestine with 3 votes.
# The winner of the Constable EAST PITTSBURGH WARD 1 contest is WRITE-IN with 2 votes.
# The winner of the Constable EAST PITTSBURGH WARD 2 contest is WRITE-IN with 2 votes.
# The winner of the Constable EAST PITTSBURGH WARD 3 contest is WRITE-IN with 2 votes.
# The winner of the Constable EDGEWOOD contest is Gregory A. Evashavik with 3 votes.
# The winner of the Constable EDGEWORTH contest is WRITE-IN with 2 votes.
# The winner of the Constable ELIZABETH BOROUGH contest is WRITE-IN with 2 votes.
# The winner of the Constable ELIZABETH TOWNSHIP contest is Edward J. Campbell, Jr. with 4 votes.
# The winner of the Constable EMSWORTH contest is WRITE-IN with 3 votes.
# The winner of the Constable ETNA WARD 1 contest is WRITE-IN with 2 votes.
# The winner of the Constable ETNA WARD 2 contest is WRITE-IN with 2 votes.
# The winner of the Constable ETNA WARD 3 contest is WRITE-IN with 2 votes.
# The winner of the Constable FAWN contest is WRITE-IN with 2 votes.
# The winner of the Constable FINDLAY contest is WRITE-IN with 2 votes.
# The winner of the Constable FOREST HILLS contest is WRITE-IN with 2 votes.
# The winner of the Constable FORWARD contest is Christopher R. Trail with 3 votes.
# The winner of the Constable FOX CHAPEL contest is WRITE-IN with 3 votes.
# The winner of the Constable FRANKLIN PARK WARD 1 contest is WRITE-IN with 2 votes.
# The winner of the Constable FRANKLIN PARK WARD 2 contest is WRITE-IN with 2 votes.
# The winner of the Constable FRANKLIN PARK WARD 3 contest is WRITE-IN with 2 votes.
# The winner of the Constable FRAZER contest is WRITE-IN with 2 votes.
# The winner of the Constable GLASSPORT contest is Joseph J. Steffan with 3 votes.
# The winner of the Constable GLEN OSBORNE contest is WRITE-IN with 2 votes.
# The winner of the Constable GLENFIELD contest is WRITE-IN with 2 votes.
# The winner of the Constable GREEN TREE contest is WRITE-IN with 3 votes.
# The winner of the Constable HAMPTON contest is Daniel J. Glock with 5 votes.
# The winner of the Constable HARMAR contest is WRITE-IN with 2 votes.
# The winner of the Constable HARRISON contest is WRITE-IN with 3 votes.
# The winner of the Constable HAYSVILLE contest is WRITE-IN with 2 votes.
# The winner of the Constable HEIDELBERG contest is James B. McIntyre with 3 votes.
# The winner of the Constable HOMESTEAD WARD 1 contest is WRITE-IN with 2 votes.
# The winner of the Constable HOMESTEAD WARD 2 contest is WRITE-IN with 2 votes.
# The winner of the Constable HOMESTEAD WARD 3 contest is WRITE-IN with 0 votes.
# The winner of the Constable INDIANA contest is David Allison with 3 votes.
# The winner of the Constable INGRAM contest is WRITE-IN with 2 votes.
# The winner of the Constable JEFFERSON HILLS contest is Dale Withers with 3 votes.
# The winner of the Constable KENNEDY contest is Max Vith with 4 votes.
# The winner of the Constable KILBUCK contest is WRITE-IN with 2 votes.
# The winner of the Constable LEET contest is WRITE-IN with 0 votes.
# The winner of the Constable LEETSDALE contest is WRITE-IN with 0 votes.
# The winner of the Constable LIBERTY contest is Brandon P. Nolder, Sr. with 3 votes.
# The winner of the Constable LINCOLN contest is Jerry Cavanaugh with 3 votes.
# The winner of the Constable MARSHALL contest is WRITE-IN with 0 votes.
# The winner of the Constable MCCANDLESS contest is Nathan J. Wolfe with 4 votes.
# The winner of the Constable MCDONALD contest is WRITE-IN with 2 votes.
# The winner of the Constable MCKEES ROCKS WARD 1 contest is WRITE-IN with 3 votes.
# The winner of the Constable MCKEES ROCKS WARD 2 contest is WRITE-IN with 3 votes.
# The winner of the Constable MCKEES ROCKS WARD 3 contest is WRITE-IN with 2 votes.
# The winner of the Constable MCKEESPORT WARD 1 contest is WRITE-IN with 2 votes.
# The winner of the Constable MCKEESPORT WARD 10 contest is WRITE-IN with 2 votes.
# The winner of the Constable MCKEESPORT WARD 11 contest is Joseph Frank Clemente with 3 votes.
# The winner of the Constable MCKEESPORT WARD 12 contest is David A. Demchak with 3 votes.
# The winner of the Constable MCKEESPORT WARD 2 contest is WRITE-IN with 2 votes.
# The winner of the Constable MCKEESPORT WARD 3 contest is WRITE-IN with 2 votes.
# The winner of the Constable MCKEESPORT WARD 4 contest is WRITE-IN with 2 votes.
# The winner of the Constable MCKEESPORT WARD 5 contest is WRITE-IN with 2 votes.
# The winner of the Constable MCKEESPORT WARD 6 contest is WRITE-IN with 2 votes.
# The winner of the Constable MCKEESPORT WARD 7 contest is Harry C. Walsh with 3 votes.
# The winner of the Constable MCKEESPORT WARD 8 contest is Robert J. Burnett with 3 votes.
# The winner of the Constable MCKEESPORT WARD 9 contest is WRITE-IN with 3 votes.
# The winner of the Constable MILLVALE contest is WRITE-IN with 0 votes.
# The winner of the Constable MONROEVILLE WARD 1 contest is Robert Bacco with 3 votes.
# The winner of the Constable MONROEVILLE WARD 2 contest is WRITE-IN with 0 votes.
# The winner of the Constable MONROEVILLE WARD 3 contest is WRITE-IN with 2 votes.
# The winner of the Constable MONROEVILLE WARD 4 contest is Thomas Marcin with 3 votes.
# The winner of the Constable MONROEVILLE WARD 5 contest is Glenn Smeltz with 3 votes.
# The winner of the Constable MONROEVILLE WARD 6 contest is Keith L. Lipsie, Jr. with 3 votes.
# The winner of the Constable MONROEVILLE WARD 7 contest is WRITE-IN with 2 votes.
# The winner of the Constable MOON contest is WRITE-IN with 0 votes.
# The winner of the Constable MT LEBANON contest is WRITE-IN with 4 votes.
# The winner of the Constable MT OLIVER contest is WRITE-IN with 3 votes.
# The winner of the Constable MUNHALL contest is David J. Younkins, Sr. with 4 votes.
# The winner of the Constable NEVILLE contest is James K. Claytor with 4 votes.
# The winner of the Constable NORTH BRADDOCK WARD 1 contest is WRITE-IN with 3 votes.
# The winner of the Constable NORTH BRADDOCK WARD 2 contest is Carl Ayres, Jr. with 3 votes.
# The winner of the Constable NORTH BRADDOCK WARD 3 contest is WRITE-IN with 2 votes.
# The winner of the Constable NORTH FAYETTE contest is WRITE-IN with 2 votes.
# The winner of the Constable NORTH VERSAILLES contest is Michael Savulak with 4 votes.
# The winner of the Constable OAKDALE contest is Lyle Grover with 4 votes.
# The winner of the Constable OAKMONT contest is WRITE-IN with 3 votes.
# The winner of the Constable OHARA contest is WRITE-IN with 3 votes.
# The winner of the Constable OHIO contest is WRITE-IN with 2 votes.
# The winner of the Constable PENN HILLS contest is Joseph F. O'Connor with 6 votes.
# The winner of the Constable PENNSBURY VILLAGE contest is WRITE-IN with 3 votes.
# The winner of the Constable PINE contest is WRITE-IN with 0 votes.
# The winner of the Constable PITCAIRN contest is WRITE-IN with 0 votes.
# The winner of the Constable PITTSBURGH WARD 1 contest is Tonya D. Payne with 3 votes.
# The winner of the Constable PITTSBURGH WARD 10 contest is Phillip A. Ionadi, Sr. with 3 votes.
# The winner of the Constable PITTSBURGH WARD 11 contest is WRITE-IN with 2 votes.
# The winner of the Constable PITTSBURGH WARD 12 contest is WRITE-IN with 3 votes.
# The winner of the Constable PITTSBURGH WARD 13 contest is WRITE-IN with 4 votes.
# The winner of the Constable PITTSBURGH WARD 14 contest is William N. Leiber with 3 votes.
# The winner of the Constable PITTSBURGH WARD 15 contest is Christian Gabriel Constantini with 3 votes.
# The winner of the Constable PITTSBURGH WARD 16 contest is WRITE-IN with 0 votes.
# The winner of the Constable PITTSBURGH WARD 17 contest is WRITE-IN with 3 votes.
# The winner of the Constable PITTSBURGH WARD 18 contest is WRITE-IN with 3 votes.
# The winner of the Constable PITTSBURGH WARD 19 contest is WRITE-IN with 0 votes.
# The winner of the Constable PITTSBURGH WARD 2 contest is WRITE-IN with 2 votes.
# The winner of the Constable PITTSBURGH WARD 20 contest is WRITE-IN with 0 votes.
# The winner of the Constable PITTSBURGH WARD 21 contest is WRITE-IN with 0 votes.
# The winner of the Constable PITTSBURGH WARD 22 contest is Robert L. Lewis, Sr. with 3 votes.
# The winner of the Constable PITTSBURGH WARD 23 contest is Kennneth Minton with 4 votes.
# The winner of the Constable PITTSBURGH WARD 24 contest is Mike W. Yost with 4 votes.
# The winner of the Constable PITTSBURGH WARD 25 contest is WRITE-IN with 2 votes.
# The winner of the Constable PITTSBURGH WARD 26 contest is WRITE-IN with 4 votes.
# The winner of the Constable PITTSBURGH WARD 27 contest is Ronald J, Hunt, Sr. with 4 votes.
# The winner of the Constable PITTSBURGH WARD 28 contest is Ronald J. Freyermuth with 3 votes.
# The winner of the Constable PITTSBURGH WARD 29 contest is WRITE-IN with 0 votes.
# The winner of the Constable PITTSBURGH WARD 3 contest is WRITE-IN with 3 votes.
# The winner of the Constable PITTSBURGH WARD 30 contest is John Dell with 4 votes.
# The winner of the Constable PITTSBURGH WARD 31 contest is James M. Emswiller with 3 votes.
# The winner of the Constable PITTSBURGH WARD 32 contest is Tony Sanner with 3 votes.
# The winner of the Constable PITTSBURGH WARD 4 contest is WRITE-IN with 3 votes.
# The winner of the Constable PITTSBURGH WARD 5 contest is Mark Lee Reed with 4 votes.
# The winner of the Constable PITTSBURGH WARD 6 contest is WRITE-IN with 0 votes.
# The winner of the Constable PITTSBURGH WARD 7 contest is WRITE-IN with 0 votes.
# The winner of the Constable PITTSBURGH WARD 8 contest is WRITE-IN with 2 votes.
# The winner of the Constable PITTSBURGH WARD 9 contest is WRITE-IN with 0 votes.
# The winner of the Constable PLEASANT HILLS contest is Connor McGrail with 3 votes.
# The winner of the Constable PLUM contest is Fred Bruce with 3 votes.
# The winner of the Constable PORT VUE contest is WRITE-IN with 3 votes.
# The winner of the Constable RANKIN WARD 1 contest is WRITE-IN with 3 votes.
# The winner of the Constable RANKIN WARD 2 contest is Lawrence A. Connor with 3 votes.
# The winner of the Constable RANKIN WARD 3 contest is Nekodi Mudd with 3 votes.
# The winner of the Constable RESERVE contest is WRITE-IN with 3 votes.
# The winner of the Constable RICHLAND contest is Vince J. Bacho with 4 votes.
# The winner of the Constable ROBINSON contest is WRITE-IN with 0 votes.
# The winner of the Constable ROSS contest is James M. Cillo with 4 votes.
# The winner of the Constable ROSSLYN FARMS contest is Charles J. Arcoletti with 3 votes.
# The winner of the Constable SCOTT contest is Bradley Skees with 4 votes.
# The winner of the Constable SEWICKLEY HEIGHTS contest is WRITE-IN with 2 votes.
# The winner of the Constable SEWICKLEY HILLS contest is Allen Dufala with 4 votes.
# The winner of the Constable SEWICKLEY WARD 1 contest is WRITE-IN with 2 votes.
# The winner of the Constable SEWICKLEY WARD 2 contest is WRITE-IN with 2 votes.
# The winner of the Constable SEWICKLEY WARD 3 contest is WRITE-IN with 2 votes.
# The winner of the Constable SHALER contest is Edward M. Stankovic with 4 votes.
# The winner of the Constable SHARPSBURG contest is WRITE-IN with 2 votes.
# The winner of the Constable SOUTH FAYETTE contest is Frank E. DeThomas with 5 votes.
# The winner of the Constable SOUTH PARK contest is Leo A. Gigliotti with 3 votes.
# The winner of the Constable SOUTH VERSAILLES contest is WRITE-IN with 0 votes.
# The winner of the Constable SPRINGDALE BOROUGH contest is WRITE-IN with 2 votes.
# The winner of the Constable SPRINGDALE TOWNSHIP contest is WRITE-IN with 0 votes.
# The winner of the Constable STOWE contest is Joseph P. Faloshey with 4 votes.
# The winner of the Constable SWISSVALE contest is Francis Keyes with 3 votes.
# The winner of the Constable TARENTUM WARD 1 contest is WRITE-IN with 2 votes.
# The winner of the Constable TARENTUM WARD 2 contest is Jeffrey C. Killian with 3 votes.
# The winner of the Constable TARENTUM WARD 3 contest is WRITE-IN with 2 votes.
# The winner of the Constable THORNBURG contest is WRITE-IN with 2 votes.
# The winner of the Constable TRAFFORD contest is Zackery L. Cole with 3 votes.
# The winner of the Constable TURTLE CREEK WARD 1 contest is WRITE-IN with 2 votes.
# The winner of the Constable TURTLE CREEK WARD 2 contest is WRITE-IN with 2 votes.
# The winner of the Constable TURTLE CREEK WARD 3 contest is Christopher Conley with 3 votes.
# The winner of the Constable UPPER ST CLAIR contest is WRITE-IN with 3 votes.
# The winner of the Constable VERONA contest is WRITE-IN with 2 votes.
# The winner of the Constable VERSAILLES contest is WRITE-IN with 2 votes.
# The winner of the Constable WALL contest is WRITE-IN with 0 votes.
# The winner of the Constable WEST DEER contest is Albert M. Dancisin with 3 votes.
# The winner of the Constable WEST ELIZABETH contest is WRITE-IN with 2 votes.
# The winner of the Constable WEST HOMESTEAD contest is John J. Karafa, Jr. with 3 votes.
# The winner of the Constable WEST MIFFLIN contest is David Parkinson with 5 votes.
# The winner of the Constable WEST VIEW contest is WRITE-IN with 0 votes.
# The winner of the Constable WHITAKER contest is WRITE-IN with 3 votes.
# The winner of the Constable WHITE OAK contest is WRITE-IN with 2 votes.
# The winner of the Constable WHITEHALL contest is WRITE-IN with 2 votes.
# The winner of the Constable WILKINS contest is Phil Dodge with 4 votes.
# The winner of the Constable WILKINSBURG WARD 1 contest is Lonzo Boyce, Sr. with 3 votes.
# The winner of the Constable WILKINSBURG WARD 2 contest is WRITE-IN with 3 votes.
# The winner of the Constable WILKINSBURG WARD 3 contest is Willie Sanders with 4 votes.
# The winner of the Constable WILMERDING contest is WRITE-IN with 0 votes.
# The winner of the Controller CITYWIDE contest is WRITE-IN with 4 votes.
# The winner of the Controller HAMPTON contest is Jerry Speakman with 3 votes.
# The winner of the Controller PENN HILLS contest is WRITE-IN with 3 votes.
# The winner of the County Chief Executive contest is WRITE-IN with 3 votes.
# The winner of the County Controller contest is WRITE-IN with 4 votes.
# The winner of the County Treasurer contest is John K. Weinstein with 3 votes.
# The winner of the District Attorney contest is WRITE-IN with 3 votes.
# The winner of the Judge of the Commonwealth Court contest is Todd Eagen with 5 votes.
# The winner of the Judge of the Court of Common Pleas contest is Jennifer Staley McCrady with 17 votes.
# The winner of the Judge of the Superior Court contest is Alice Beck Dubow with 5 votes.
# The winner of the Justice of the Supreme Court contest is Kevin M. Dougherty with 14 votes.
# The winner of the Magisterial District Judge 05-02-02 contest is Richard G. Opiela with 4 votes.
# The winner of the Magisterial District Judge 05-02-04 contest is Barry Wingard with 0 votes.
# The winner of the Magisterial District Judge 05-02-06 contest is John Petrucci with 10 votes.
# The winner of the Magisterial District Judge 05-02-11 contest is Rodger J. Blissman with 10 votes.
# The winner of the Magisterial District Judge 05-02-17 contest is David Barton with 4 votes.
# The winner of the Magisterial District Judge 05-02-18 contest is Ralph E. Miller with 0 votes.
# The winner of the Magisterial District Judge 05-02-19 contest is Blaise P. Larotonda with 4 votes.
# The winner of the Magisterial District Judge 05-02-20 contest is Ron Arnoni with 8 votes.
# The winner of the Magisterial District Judge 05-02-21 contest is Maureen McGraw-Desmet with 4 votes.
# The winner of the Magisterial District Judge 05-02-22 contest is Craig Stephens with 9 votes.
# The winner of the Magisterial District Judge 05-02-25 contest is Mary P. Murray with 7 votes.
# The winner of the Magisterial District Judge 05-02-38 contest is Jim Motznik with 4 votes.
# The winner of the Magisterial District Judge 05-02-40 contest is WRITE-IN with 6 votes.
# The winner of the Magisterial District Judge 05-02-42 contest is Brian Weismantle with 8 votes.
# The winner of the Magisterial District Judge 05-02-47 contest is Scott H. Schricker with 3 votes.
# The winner of the Magisterial District Judge 05-03-04 contest is Joseph Shurina with 20 votes.
# The winner of the Magisterial District Judge 05-03-05 contest is Thomas G. Miller, Jr. with 4 votes.
# The winner of the Magisterial District Judge 05-03-09 contest is Armand A. Martin with 4 votes.
# The winner of the Magisterial District Judge 05-03-10 contest is Tony Ceoffe with 3 votes.
# The winner of the Magisterial District Judge 05-03-12 contest is WRITE-IN with 5 votes.
# The winner of the Mayor GLENFIELD contest is Michael A. Cherock with 3 votes.
# The winner of the Mayor HAYSVILLE contest is WRITE-IN with 2 votes.
# The winner of the Mayor MCKEESPORT contest is WRITE-IN with 4 votes.
# The winner of the Mayor PENN HILLS contest is WRITE-IN with 3 votes.
# The winner of the Mayor WALL contest is WRITE-IN with 2 votes.
# The winner of the Mayor WEST ELIZABETH contest is WRITE-IN with 0 votes.
# The winner of the Mayor WILMERDING contest is WRITE-IN with 3 votes.
# The winner of the Member of Council ASPINWALL contest is WRITE-IN with 0 votes.
# The winner of the Member of Council AVALON WARD 1 contest is WRITE-IN with 3 votes.
# The winner of the Member of Council AVALON WARD 2 contest is WRITE-IN with 0 votes.
# The winner of the Member of Council AVALON WARD 3 contest is WRITE-IN with 3 votes.
# The winner of the Member of Council At-Large EAST PITTSBURGH contest is Dennis  J. Simon with 4 votes.
# The winner of the Member of Council At-Large OHARA contest is James Zaenger with 6 votes.
# The winner of the Member of Council At-Large TARENTUM contest is WRITE-IN with 4 votes.
# The winner of the Member of Council BALDWIN BOROUGH contest is Robert T. Collet with 11 votes.
# The winner of the Member of Council BELL ACRES contest is WRITE-IN with 5 votes.
# The winner of the Member of Council BELLEVUE WARD 1 contest is Linda Woshner with 5 votes.
# The winner of the Member of Council BELLEVUE WARD 2 contest is Thomas M. Hrynda with 3 votes.
# The winner of the Member of Council BELLEVUE WARD 3 contest is WRITE-IN with 5 votes.
# The winner of the Member of Council BEN AVON contest is WRITE-IN with 0 votes.
# The winner of the Member of Council BEN AVON HEIGHTS contest is WRITE-IN with 2 votes.
# The winner of the Member of Council BETHEL PARK WARD 2 contest is Brandon Colella with 3 votes.
# The winner of the Member of Council BETHEL PARK WARD 4 contest is WRITE-IN with 3 votes.
# The winner of the Member of Council BETHEL PARK WARD 6 contest is Mark J. O'Brien with 3 votes.
# The winner of the Member of Council BETHEL PARK WARD 8 contest is WRITE-IN with 3 votes.
# The winner of the Member of Council BLAWNOX contest is Kathryn Specht Coban with 7 votes.
# The winner of the Member of Council BRACKENRIDGE WARD 1 contest is WRITE-IN with 0 votes.
# The winner of the Member of Council BRACKENRIDGE WARD 2 contest is John Stanzione, Jr. with 3 votes.
# The winner of the Member of Council BRACKENRIDGE WARD 3 contest is Verne F. Petz, Sr. with 3 votes.
# The winner of the Member of Council BRADDOCK HILLS contest is Michael Ursiny with 5 votes.
# The winner of the Member of Council BRADDOCK WARD 1 contest is WRITE-IN with 2 votes.
# The winner of the Member of Council BRADDOCK WARD 2 contest is WRITE-IN with 3 votes.
# The winner of the Member of Council BRADDOCK WARD 3 contest is WRITE-IN with 0 votes.
# The winner of the Member of Council BRADFORD WOODS contest is Thomas Kosmala with 0 votes.
# The winner of the Member of Council BRENTWOOD contest is Adrian Matthew Doyle with 2 votes.
# The winner of the Member of Council BRIDGEVILLE contest is Mary C. Weise with 12 votes.
# The winner of the Member of Council CARNEGIE WARD 1 contest is Blair Clover with 6 votes.
# The winner of the Member of Council CARNEGIE WARD 2 contest is WRITE-IN with 4 votes.
# The winner of the Member of Council CASTLE SHANNON contest is Marian L. Randazzo with 5 votes.
# The winner of the Member of Council CHALFANT contest is Joanne M. Baburich with 5 votes.
# The winner of the Member of Council CHESWICK contest is WRITE-IN with 5 votes.
# The winner of the Member of Council CHURCHILL contest is Jay Dworin with 3 votes.
# The winner of the Member of Council CLAIRTON WARD 1 contest is John A. Lattanzi with 3 votes.
# The winner of the Member of Council CLAIRTON WARD 4 contest is Denise Johnson with 4 votes.
# The winner of the Member of Council CORAOPOLIS WARD 1 contest is Calvin L. Jackson, Jr. with 3 votes.
# The winner of the Member of Council CORAOPOLIS WARD 2 contest is WRITE-IN with 0 votes.
# The winner of the Member of Council CORAOPOLIS WARD 3 contest is Danielle Alyce Burnette with 4 votes.
# The winner of the Member of Council CORAOPOLIS WARD 4 contest is WRITE-IN with 0 votes.
# The winner of the Member of Council CRAFTON contest is WRITE-IN with 0 votes.
# The winner of the Member of Council DISTRICT 1 contest is WRITE-IN with 5 votes.
# The winner of the Member of Council DISTRICT 3 contest is Bruce A. Kraus with 3 votes.
# The winner of the Member of Council DISTRICT 5 contest is WRITE-IN with 0 votes.
# The winner of the Member of Council DISTRICT 7 contest is WRITE-IN with 0 votes.
# The winner of the Member of Council DISTRICT 9 contest is Ricky V. Burgess with 6 votes.
# The winner of the Member of Council DORMONT contest is Kate Abel with 8 votes.
# The winner of the Member of Council DRAVOSBURG contest is Matthew L. Mols with 4 votes.
# The winner of the Member of Council DUQUESNE contest is Eugene Capristo with 6 votes.
# The winner of the Member of Council EAST MCKEESPORT contest is Kathleen H. Lipesky with 7 votes.
# The winner of the Member of Council EDGEWOOD contest is WRITE-IN with 5 votes.
# The winner of the Member of Council EDGEWORTH contest is Gary  Lee Smith with 5 votes.
# The winner of the Member of Council ELIZABETH BOROUGH contest is WRITE-IN with 0 votes.
# The winner of the Member of Council EMSWORTH contest is WRITE-IN with 2 votes.
# The winner of the Member of Council ETNA WARD 1 contest is Gregory Porter with 4 votes.
# The winner of the Member of Council ETNA WARD 2 contest is Ronald Trader with 3 votes.
# The winner of the Member of Council ETNA WARD 3 contest is WRITE-IN with 3 votes.
# The winner of the Member of Council FOREST HILLS contest is William I. Burleigh with 5 votes.
# The winner of the Member of Council FOX CHAPEL contest is Ann R. Meyer with 5 votes.
# The winner of the Member of Council FRANKLIN PARK WARD 1 contest is Laura A. Coombs with 3 votes.
# The winner of the Member of Council FRANKLIN PARK WARD 2 contest is WRITE-IN with 3 votes.
# The winner of the Member of Council FRANKLIN PARK WARD 3 contest is James W. Lawrence with 3 votes.
# The winner of the Member of Council GLASSPORT contest is Thomas W. Bradley, Jr. with 8 votes.
# The winner of the Member of Council GLEN OSBORNE contest is Thomas A. Huddleston with 0 votes.
# The winner of the Member of Council GLENFIELD contest is WRITE-IN with 0 votes.
# The winner of the Member of Council GREEN TREE contest is WRITE-IN with 7 votes.
# The winner of the Member of Council HAMPTON contest is Sherry Neugebauer with 4 votes.
# The winner of the Member of Council HAYSVILLE contest is WRITE-IN with 0 votes.
# The winner of the Member of Council HEIDELBERG contest is WRITE-IN with 6 votes.
# The winner of the Member of Council HOMESTEAD WARD 1 contest is Wanda Burwell with 3 votes.
# The winner of the Member of Council HOMESTEAD WARD 2 contest is Barbara M. Broadwater with 3 votes.
# The winner of the Member of Council HOMESTEAD WARD 3 contest is Susan Titmus with 4 votes.
# The winner of the Member of Council INGRAM contest is WRITE-IN with 5 votes.
# The winner of the Member of Council JEFFERSON HILLS contest is WRITE-IN with 0 votes.
# The winner of the Member of Council LEETSDALE contest is WRITE-IN with 9 votes.
# The winner of the Member of Council LIBERTY contest is WRITE-IN with 5 votes.
# The winner of the Member of Council LINCOLN contest is Paul S. Vereb with 5 votes.
# The winner of the Member of Council MCCANDLESS WARD 1 contest is Cynthia Potter with 4 votes.
# The winner of the Member of Council MCCANDLESS WARD 3 contest is Roger Krey with 4 votes.
# The winner of the Member of Council MCCANDLESS WARD 5 contest is WRITE-IN with 4 votes.
# The winner of the Member of Council MCCANDLESS WARD 7 contest is WRITE-IN with 0 votes.
# The winner of the Member of Council MCDONALD contest is Michael C. Schaal with 0 votes.
# The winner of the Member of Council MCKEES ROCKS WARD 1 contest is Sarah Elizabeth Harvey with 4 votes.
# The winner of the Member of Council MCKEES ROCKS WARD 3 contest is John Ciangiarulo, Jr. with 7 votes.
# The winner of the Member of Council MCKEESPORT contest is Keith A. Soles with 9 votes.
# The winner of the Member of Council MILLVALE contest is Jason Miller with 6 votes.
# The winner of the Member of Council MONROEVILLE WARD 2 contest is WRITE-IN with 0 votes.
# The winner of the Member of Council MONROEVILLE WARD 4 contest is James C. Johns, Jr. with 3 votes.
# The winner of the Member of Council MONROEVILLE WARD 6 contest is WRITE-IN with 3 votes.
# The winner of the Member of Council MT OLIVER contest is Amber McGough with 7 votes.
# The winner of the Member of Council MUNHALL contest is John J. Tichon with 12 votes.
# The winner of the Member of Council NORTH BRADDOCK WARD 1 contest is Michael Dobrinich with 3 votes.
# The winner of the Member of Council NORTH BRADDOCK WARD 2 contest is WRITE-IN with 3 votes.
# The winner of the Member of Council NORTH BRADDOCK WARD 3 contest is Richard Jay Kostyak with 4 votes.
# The winner of the Member of Council OAKDALE contest is Mark A. Maximovich with 5 votes.
# The winner of the Member of Council OAKMONT contest is William E. Benusa with 9 votes.
# The winner of the Member of Council PENN HILLS contest is WRITE-IN with 5 votes.
# The winner of the Member of Council PENNSBURY VILLAGE contest is WRITE-IN with 5 votes.
# The winner of the Member of Council PITCAIRN contest is John J. Rocco with 8 votes.
# The winner of the Member of Council PLEASANT HILLS contest is WRITE-IN with 5 votes.
# The winner of the Member of Council PLUM contest is David M. Seitz with 7 votes.
# The winner of the Member of Council PORT VUE contest is Greg M. Lombardo with 6 votes.
# The winner of the Member of Council RANKIN WARD 1 contest is Ruby M. Grant with 3 votes.
# The winner of the Member of Council RANKIN WARD 2 contest is Geneva Parks with 3 votes.
# The winner of the Member of Council RANKIN WARD 3 contest is WRITE-IN with 3 votes.
# The winner of the Member of Council ROSSLYN FARMS contest is WRITE-IN with 0 votes.
# The winner of the Member of Council SEWICKLEY HEIGHTS contest is WRITE-IN with 0 votes.
# The winner of the Member of Council SEWICKLEY HILLS contest is WRITE-IN with 2 votes.
# The winner of the Member of Council SEWICKLEY WARD 1 contest is WRITE-IN with 3 votes.
# The winner of the Member of Council SEWICKLEY WARD 2 contest is WRITE-IN with 4 votes.
# The winner of the Member of Council SEWICKLEY WARD 3 contest is WRITE-IN with 7 votes.
# The winner of the Member of Council SHARPSBURG contest is Lawrence A. Trozzo with 5 votes.
# The winner of the Member of Council SPRINGDALE BOROUGH contest is WRITE-IN with 8 votes.
# The winner of the Member of Council SWISSVALE contest is Darrell Rapp with 9 votes.
# The winner of the Member of Council TARENTUM WARD 1 contest is WRITE-IN with 0 votes.
# The winner of the Member of Council TARENTUM WARD 2 contest is Eric Carter with 4 votes.
# The winner of the Member of Council TARENTUM WARD 3 contest is Timothy Firko with 7 votes.
# The winner of the Member of Council THORNBURG contest is WRITE-IN with 0 votes.
# The winner of the Member of Council TRAFFORD contest is WRITE-IN with 6 votes.
# The winner of the Member of Council TURTLE CREEK WARD 1 contest is Constance Marie Tinsley with 4 votes.
# The winner of the Member of Council TURTLE CREEK WARD 2 contest is Jill E. Henkel with 4 votes.
# The winner of the Member of Council TURTLE CREEK WARD 3 contest is Max E. Spencer, Jr. with 3 votes.
# The winner of the Member of Council VERONA contest is Sylvia K. Provenza with 8 votes.
# The winner of the Member of Council VERSAILLES contest is William E. Kruczek with 6 votes.
# The winner of the Member of Council WALL contest is WRITE-IN with 2 votes.
# The winner of the Member of Council WEST ELIZABETH contest is Lewis Miller with 5 votes.
# The winner of the Member of Council WEST HOMESTEAD contest is Joseph M. Baran with 6 votes.
# The winner of the Member of Council WEST MIFFLIN contest is Michael G. Moses with 8 votes.
# The winner of the Member of Council WEST VIEW contest is M. Kimberly Steele with 5 votes.
# The winner of the Member of Council WHITAKER contest is Robert T. Asson, Sr. with 5 votes.
# The winner of the Member of Council WHITE OAK contest is Richard Keller with 8 votes.
# The winner of the Member of Council WHITEHALL contest is Glenn Nagy with 10 votes.
# The winner of the Member of Council WILKINSBURG WARD 1 contest is Paige E. Trice with 5 votes.
# The winner of the Member of Council WILKINSBURG WARD 2 contest is Vanessa McCarthy-Johnson with 3 votes.
# The winner of the Member of Council WILKINSBURG WARD 3 contest is Kate McEvoy Grannemann with 3 votes.
# The winner of the Member of Council WILMERDING contest is Karen Peterson with 8 votes.
# The winner of the Member of County Council At-Large contest is John P. DeFazio with 4 votes.
# The winner of the Member of County Council DISTRICT 10 contest is WRITE-IN with 3 votes.
# The winner of the Member of County Council DISTRICT 11 contest is Barbara Daly Danko with 4 votes.
# The winner of the Member of County Council DISTRICT 13 contest is Denise Ranalli-Russell with 4 votes.
# The winner of the Member of County Council DISTRICT 2 contest is Cindy Kirk with 0 votes.
# The winner of the Member of County Council DISTRICT 5 contest is WRITE-IN with 3 votes.
# The winner of the Member of County Council DISTRICT 6 contest is WRITE-IN with 3 votes.
# The winner of the Member of County Council DISTRICT 7 contest is WRITE-IN with 0 votes.
# The winner of the School Director ALLEGHENY VALLEY contest is Elizabeth Ann Moretti with 14 votes.
# The winner of the School Director AVONWORTH contest is WRITE-IN with 10 votes.
# The winner of the School Director At Large v3 t4 STEEL VALLEY contest is Kathy M. Ligeros with 18 votes.
# The winner of the School Director At-Large CLAIRTON contest is Gloria Ruffing with 3 votes.
# The winner of the School Director At-Large STO-ROX contest is WRITE-IN with 0 votes.
# The winner of the School Director At-Large v1 t2 STO-ROX contest is Maura J. Mitchell with 4 votes.
# The winner of the School Director BALDWIN WHITEHALL contest is Tracy L. Macek with 24 votes.
# The winner of the School Director BETHEL PARK contest is WRITE-IN with 10 votes.
# The winner of the School Director BRENTWOOD contest is Dominic E. Woods, Sr. with 0 votes.
# The winner of the School Director CARLYNTON contest is Jim Schriver with 12 votes.
# The winner of the School Director CHARTIERS VALLEY contest is Mark Kuczinski with 12 votes.
# The winner of the School Director CLAIRTON REGION 1 contest is Kathy Santoline with 3 votes.
# The winner of the School Director CLAIRTON REGION 2 contest is WRITE-IN with 0 votes.
# The winner of the School Director CLAIRTON REGION 3 contest is WRITE-IN with 3 votes.
# The winner of the School Director CLAIRTON REGION 4 contest is Roger Tachoir with 4 votes.
# The winner of the School Director CORNELL contest is Linda Solecki with 0 votes.
# The winner of the School Director DEER LAKES contest is Leanna Mae Shurina with 0 votes.
# The winner of the School Director DISTRICT 2 contest is Regina B. Holley with 4 votes.
# The winner of the School Director DISTRICT 4 contest is Lynda Wrenn with 6 votes.
# The winner of the School Director DISTRICT 6 contest is Moira B. Kaleida with 8 votes.
# The winner of the School Director DISTRICT 8 contest is Rosemary Moriarty with 6 votes.
# The winner of the School Director DUQUESNE contest is WRITE-IN with 6 votes.
# The winner of the School Director EAST ALLEGHENY REGION 1 contest is Gerri C. McCullough with 4 votes.
# The winner of the School Director EAST ALLEGHENY REGION 5 contest is Frederick Miller with 6 votes.
# The winner of the School Director EAST ALLEGHENY REGION 6 contest is WRITE-IN with 0 votes.
# The winner of the School Director EAST ALLEGHENY REGION 8 contest is John Paul Savinda, Jr. with 4 votes.
# The winner of the School Director EAST ALLEGHENY REGION 9 contest is Lisa M. Green with 4 votes.
# The winner of the School Director ELIZABETH FORWARD contest is Philip Martell with 16 votes.
# The winner of the School Director FORT CHERRY contest is Melinda Errett with 12 votes.
# The winner of the School Director FOX CHAPEL REGION 1 contest is WRITE-IN with 5 votes.
# The winner of the School Director FOX CHAPEL REGION 2 contest is Sandra M. Garbisch with 6 votes.
# The winner of the School Director FOX CHAPEL REGION 3 contest is Nancy B. Foster with 4 votes.
# The winner of the School Director GATEWAY contest is Mary Beth Cirucci with 25 votes.
# The winner of the School Director HAMPTON contest is Larry Vasko with 12 votes.
# The winner of the School Director HIGHLANDS REGION 1 contest is WRITE-IN with 0 votes.
# The winner of the School Director HIGHLANDS REGION 2 contest is Jeff Mundy with 4 votes.
# The winner of the School Director HIGHLANDS REGION 3 contest is Ryan E. Hanford with 6 votes.
# The winner of the School Director KEYSTONE OAKS REGION 1 contest is Raeann Lindsey with 4 votes.
# The winner of the School Director KEYSTONE OAKS REGION 2 contest is Robert D. Brownlee with 5 votes.
# The winner of the School Director KEYSTONE OAKS REGION 3 contest is Theresa A. Lydon with 6 votes.
# The winner of the School Director MCKEESPORT AREA contest is Joe Lopretto with 14 votes.
# The winner of the School Director MONTOUR REGION 1 contest is Thomas Barclay with 7 votes.
# The winner of the School Director MONTOUR REGION 2 contest is Edwin Miller with 0 votes.
# The winner of the School Director MOON AREA contest is A. Michael Olszewski with 23 votes.
# The winner of the School Director MT LEBANON contest is Lawrence Mark Lebowitz with 13 votes.
# The winner of the School Director NORTH ALLEGHENY contest is Maureen Grosheider with 16 votes.
# The winner of the School Director NORTH HILLS contest is Tom Kelly with 18 votes.
# The winner of the School Director NORTHGATE contest is Timothy J. Makatura with 12 votes.
# The winner of the School Director NORWIN contest is Robert Perkins with 20 votes.
# The winner of the School Director PENN -TRAFFORD contest is Nick A. Petrucci with 7 votes.
# The winner of the School Director PENN HILLS contest is Catherine M. Mowry with 17 votes.
# The winner of the School Director PINE RICHLAND REGION 1 contest is Therese M. Dawson with 9 votes.
# The winner of the School Director PINE RICHLAND REGION 2 contest is Peter Lyons with 4 votes.
# The winner of the School Director PINE RICHLAND REGION 3 contest is Virginia Goebel with 6 votes.
# The winner of the School Director PLUM contest is Louis J. Lazzaro with 22 votes.
# The winner of the School Director QUAKER VALLEY REGION 1 contest is Gianni Floro with 4 votes.
# The winner of the School Director QUAKER VALLEY REGION 2 contest is David P. Pusateri with 6 votes.
# The winner of the School Director QUAKER VALLEY REGION 3 contest is Jeffrey M. Watters with 6 votes.
# The winner of the School Director RIVERVIEW contest is Jon Nehlsen with 14 votes.
# The winner of the School Director SHALER AREA REGION 1 contest is Jim Tunstall with 6 votes.
# The winner of the School Director SHALER AREA REGION 2 contest is Eileen J. Phillips with 10 votes.
# The winner of the School Director SHALER AREA REGION 3 contest is James L. Fisher with 10 votes.
# The winner of the School Director SOUTH ALLEGHENY contest is Timothy V. Wackowski with 13 votes.
# The winner of the School Director SOUTH FAYETTE contest is Paul Brinsky with 12 votes.
# The winner of the School Director SOUTH PARK contest is Mary A. Arrigo with 12 votes.
# The winner of the School Director STEEL VALLEY REGION 2 contest is James Bulger with 6 votes.
# The winner of the School Director STEEL VALLEY REGION 3 contest is Daniel Matthew Rojtas with 6 votes.
# The winner of the School Director STO-ROX REGION 1 contest is Samantha Levitzki with 5 votes.
# The winner of the School Director STO-ROX REGION 2 contest is WRITE-IN with 3 votes.
# The winner of the School Director UPPER SAINT CLAIR contest is Phillip J. Elias with 14 votes.
# The winner of the School Director WEST ALLEGHENY REGION 1 contest is Robert A. Ostrander with 6 votes.
# The winner of the School Director WEST ALLEGHENY REGION 2 contest is Debra A. Mirich with 4 votes.
# The winner of the School Director WEST ALLEGHENY REGION 3 contest is Edward Faux with 6 votes.
# The winner of the School Director WEST JEFFERSON HILLS contest is Kerri  L. Gonot with 20 votes.
# The winner of the School Director WEST MIFFLIN AREA contest is Leonard Phillips with 36 votes.
# The winner of the School Director WILKINSBURG contest is Klara K. Brown with 12 votes.
# The winner of the School Director WOODLAND HILLS REGION 1 contest is Andre D. Moore with 8 votes.
# The winner of the School Director WOODLAND HILLS REGION 2 contest is James W. Weems, Jr. with 6 votes.
# The winner of the School Director WOODLAND HILLS REGION 3 contest is Jamie L. Glasser with 9 votes.
# The winner of the Supervisor At-Large RICHLAND contest is Donna L. Snyder with 3 votes.
# The winner of the Supervisor FAWN contest is Jason Davidek with 6 votes.
# ...
# Encrypted total votes for Gary Paladin in School Director NORTHGATE: ...
# Encrypted total votes for Shannon I. Smithey in School Director NORTHGATE: ...
# Encrypted total votes for Gary Brozek in School Director NORWIN: ...
# Encrypted total votes for Tracey L. Czajkowski in School Director NORWIN: ...
# Encrypted total votes for WRITE-IN in School Director NORWIN: ...
# Encrypted total votes for Dennis Rittenhouse in School Director NORWIN: ...
# Encrypted total votes for Robert Perkins in School Director NORWIN: ...
# Encrypted total votes for Del P. Nolfi, Jr. in School Director NORWIN: ...
# Encrypted total votes for Raymond Kocak in School Director NORWIN: ...
# Encrypted total votes for Darlene Ciocca in School Director NORWIN: ...
# Encrypted total votes for Thomas Sturm in School Director NORWIN: ...
# Encrypted total votes for Shawn Petrisko in School Director NORWIN: ...
# Encrypted total votes for Sallie Bradley in School Director PENN -TRAFFORD: ...
# Encrypted total votes for WRITE-IN in School Director PENN -TRAFFORD: ...
# Encrypted total votes for Nick A. Petrucci in School Director PENN -TRAFFORD: ...
# Encrypted total votes for Scott Koscho in School Director PENN -TRAFFORD: ...
# Encrypted total votes for WRITE-IN in School Director PENN HILLS: ...
# Encrypted total votes for Denise Graham Shealey in School Director PENN HILLS: ...
# Encrypted total votes for Catherine M. Mowry in School Director PENN HILLS: ...
# Encrypted total votes for Heather K. Hoolahan in School Director PENN HILLS: ...
# Encrypted total votes for Theresa Kotvas in School Director PENN HILLS: ...
# Encrypted total votes for Erin Vecchio in School Director PENN HILLS: ...
# Encrypted total votes for Marlon L. Ferguson in School Director PENN HILLS: ...
# Encrypted total votes for Donald L. Kuhn, Jr. in School Director PENN HILLS: ...
# Encrypted total votes for Lizz Helmsen in School Director PINE RICHLAND REGION 1: ...
# Encrypted total votes for Therese M. Dawson in School Director PINE RICHLAND REGION 1: ...
# Encrypted total votes for WRITE-IN in School Director PINE RICHLAND REGION 1: ...
# Encrypted total votes for WRITE-IN in School Director PINE RICHLAND REGION 2: ...
# Encrypted total votes for Peter Lyons in School Director PINE RICHLAND REGION 2: ...
# Encrypted total votes for WRITE-IN in School Director PINE RICHLAND REGION 3: ...
# Encrypted total votes for Virginia Goebel in School Director PINE RICHLAND REGION 3: ...
# Encrypted total votes for Laura Ohlund in School Director PINE RICHLAND REGION 3: ...
# Encrypted total votes for K. Paul Freese in School Director PLUM: ...
# Encrypted total votes for Melissa L. Russell in School Director PLUM: ...
# Encrypted total votes for Joe Tommarello in School Director PLUM: ...
# Encrypted total votes for Louis J. Lazzaro in School Director PLUM: ...
# Encrypted total votes for Vicky Roessler in School Director PLUM: ...
# Encrypted total votes for Tom McGough in School Director PLUM: ...
# Encrypted total votes for Richard G. Zucco in School Director PLUM: ...
# Encrypted total votes for Steve Schlauch in School Director PLUM: ...
# Encrypted total votes for Margie Evans in School Director PLUM: ...
# Encrypted total votes for Jim Rogers in School Director PLUM: ...
# Encrypted total votes for WRITE-IN in School Director PLUM: ...
# Encrypted total votes for WRITE-IN in School Director QUAKER VALLEY REGION 1: ...
# Encrypted total votes for Gianni Floro in School Director QUAKER VALLEY REGION 1: ...
# Encrypted total votes for Robert Riker in School Director QUAKER VALLEY REGION 2: ...
# Encrypted total votes for David P. Pusateri in School Director QUAKER VALLEY REGION 2: ...
# Encrypted total votes for WRITE-IN in School Director QUAKER VALLEY REGION 2: ...
# Encrypted total votes for WRITE-IN in School Director QUAKER VALLEY REGION 3: ...
# Encrypted total votes for Marna Karcher Blackmer in School Director QUAKER VALLEY REGION 3: ...
# Encrypted total votes for Jeffrey M. Watters in School Director QUAKER VALLEY REGION 3: ...
# Encrypted total votes for Alexander C. DiClaudio in School Director RIVERVIEW: ...
# Encrypted total votes for Ernie Tillman in School Director RIVERVIEW: ...
# Encrypted total votes for Kelly Jane Walker in School Director RIVERVIEW: ...
# Encrypted total votes for Jon Nehlsen in School Director RIVERVIEW: ...
# Encrypted total votes for WRITE-IN in School Director RIVERVIEW: ...
# Encrypted total votes for Jim Tunstall in School Director SHALER AREA REGION 1: ...
# Encrypted total votes for April Gentile-Lehmeier in School Director SHALER AREA REGION 1: ...
# Encrypted total votes for WRITE-IN in School Director SHALER AREA REGION 1: ...
# Encrypted total votes for Erin L. Autenreith in School Director SHALER AREA REGION 2: ...
# Encrypted total votes for WRITE-IN in School Director SHALER AREA REGION 2: ...
# Encrypted total votes for Jason Machajewski in School Director SHALER AREA REGION 2: ...
# Encrypted total votes for Eileen J. Phillips in School Director SHALER AREA REGION 2: ...
# Encrypted total votes for William Couts in School Director SHALER AREA REGION 2: ...
# Encrypted total votes for Chris Weaver in School Director SHALER AREA REGION 3: ...
# Encrypted total votes for Jeanne Petrovich in School Director SHALER AREA REGION 3: ...
# Encrypted total votes for WRITE-IN in School Director SHALER AREA REGION 3: ...
# Encrypted total votes for James L. Fisher in School Director SHALER AREA REGION 3: ...
# Encrypted total votes for Ronald K. Randic in School Director SOUTH ALLEGHENY: ...
# Encrypted total votes for James Jackson in School Director SOUTH ALLEGHENY: ...
# Encrypted total votes for Timothy V. Wackowski in School Director SOUTH ALLEGHENY: ...
# Encrypted total votes for WRITE-IN in School Director SOUTH ALLEGHENY: ...
# Encrypted total votes for Luke F. Riley in School Director SOUTH ALLEGHENY: ...
# Encrypted total votes for Russell A. Geary in School Director SOUTH ALLEGHENY: ...
# Encrypted total votes for Alexander J. Czaplicki in School Director SOUTH FAYETTE: ...
# Encrypted total votes for Todd Petrillo in School Director SOUTH FAYETTE: ...
# Encrypted total votes for Lena Josephine Hannah in School Director SOUTH FAYETTE: ...
# Encrypted total votes for Paul Brinsky in School Director SOUTH FAYETTE: ...
# Encrypted total votes for WRITE-IN in School Director SOUTH FAYETTE: ...
# Encrypted total votes for Teresa E. Burroughs in School Director SOUTH FAYETTE: ...
# Encrypted total votes for Mary A. Arrigo in School Director SOUTH PARK: ...
# Encrypted total votes for David E. Palmer in School Director SOUTH PARK: ...
# Encrypted total votes for WRITE-IN in School Director SOUTH PARK: ...
# Encrypted total votes for Nicholas J. Rudolph in School Director SOUTH PARK: ...
# Encrypted total votes for WRITE-IN in School Director STEEL VALLEY REGION 2: ...
# Encrypted total votes for James Bulger in School Director STEEL VALLEY REGION 2: ...
# Encrypted total votes for Daniel Matthew Rojtas in School Director STEEL VALLEY REGION 3: ...
# Encrypted total votes for WRITE-IN in School Director STEEL VALLEY REGION 3: ...
# Encrypted total votes for Donald M. Bajus in School Director STEEL VALLEY REGION 3: ...
# Encrypted total votes for Samantha Levitzki in School Director STO-ROX REGION 1: ...
# Encrypted total votes for WRITE-IN in School Director STO-ROX REGION 1: ...
# Encrypted total votes for William Lenhart in School Director STO-ROX REGION 1: ...
# Encrypted total votes for Maura J. Mitchell in School Director STO-ROX REGION 2: ...
# Encrypted total votes for WRITE-IN in School Director STO-ROX REGION 2: ...
# Encrypted total votes for Bethany Hoag-Salmen in School Director UPPER SAINT CLAIR: ...
# Encrypted total votes for Amy L. Billerbeck in School Director UPPER SAINT CLAIR: ...
# Encrypted total votes for Angela Petersen in School Director UPPER SAINT CLAIR: ...
# Encrypted total votes for Phillip J. Elias in School Director UPPER SAINT CLAIR: ...
# Encrypted total votes for WRITE-IN in School Director UPPER SAINT CLAIR: ...
# Encrypted total votes for Barbara L. Bolas in School Director UPPER SAINT CLAIR: ...
# Encrypted total votes for Robert A. Ostrander in School Director WEST ALLEGHENY REGION 1: ...
# Encrypted total votes for WRITE-IN in School Director WEST ALLEGHENY REGION 1: ...
# Encrypted total votes for Ronald F. Pasic in School Director WEST ALLEGHENY REGION 1: ...
# Encrypted total votes for Debra A. Mirich in School Director WEST ALLEGHENY REGION 2: ...
# Encrypted total votes for WRITE-IN in School Director WEST ALLEGHENY REGION 2: ...
# Encrypted total votes for Mark H. Rosen in School Director WEST ALLEGHENY REGION 3: ...
# Encrypted total votes for Edward Faux in School Director WEST ALLEGHENY REGION 3: ...
# Encrypted total votes for WRITE-IN in School Director WEST ALLEGHENY REGION 3: ...
# Encrypted total votes for Marianne L. Neel in School Director WEST JEFFERSON HILLS: ...
# Encrypted total votes for David Dominick in School Director WEST JEFFERSON HILLS: ...
# Encrypted total votes for Alan J. Caponi in School Director WEST JEFFERSON HILLS: ...
# Encrypted total votes for WRITE-IN in School Director WEST JEFFERSON HILLS: ...
# Encrypted total votes for Suzanne M. Downer in School Director WEST JEFFERSON HILLS: ...
# Encrypted total votes for Ryan Pierce in School Director WEST JEFFERSON HILLS: ...
# Encrypted total votes for Jill Achtzehn Bertini in School Director WEST JEFFERSON HILLS: ...
# Encrypted total votes for Kerri  L. Gonot in School Director WEST JEFFERSON HILLS: ...
# Encrypted total votes for NO CANDIDATE FILED in School Director WEST MIFFLIN AREA: ...
# Encrypted total votes for Janice Gladden in School Director WEST MIFFLIN AREA: ...
# Encrypted total votes for Janice L. Gladden in School Director WEST MIFFLIN AREA: ...
# Encrypted total votes for Tony DiCenzo in School Director WEST MIFFLIN AREA: ...
# Encrypted total votes for Leonard Phillips in School Director WEST MIFFLIN AREA: ...
# Encrypted total votes for Holly M. Marshall in School Director WEST MIFFLIN AREA: ...
# Encrypted total votes for Glenn Cerra in School Director WEST MIFFLIN AREA: ...
# Encrypted total votes for Stephen Kovac in School Director WEST MIFFLIN AREA: ...
# Encrypted total votes for WRITE-IN in School Director WEST MIFFLIN AREA: ...
# Encrypted total votes for Richard J. Crux in School Director WEST MIFFLIN AREA: ...
# Encrypted total votes for Harry G. Fast, III in School Director WEST MIFFLIN AREA: ...
# Encrypted total votes for Nicholas Alexandroff in School Director WEST MIFFLIN AREA: ...
# Encrypted total votes for Charles Howell in School Director WEST MIFFLIN AREA: ...
# Encrypted total votes for Daniel J. McDonald in School Director WEST MIFFLIN AREA: ...
# Encrypted total votes for Theodore Cale in School Director WEST MIFFLIN AREA: ...
# Encrypted total votes for Judith E. Andzelik in School Director WEST MIFFLIN AREA: ...
# Encrypted total votes for Klara K. Brown in School Director WILKINSBURG: ...
# Encrypted total votes for Kathy Firestine in School Director WILKINSBURG: ...
# Encrypted total votes for Joshua Miller in School Director WILKINSBURG: ...
# Encrypted total votes for WRITE-IN in School Director WILKINSBURG: ...
# Encrypted total votes for Cicely M. Jackson-Hanner in School Director WOODLAND HILLS REGION 1: ...
# Encrypted total votes for Jeffrey Hildebrand in School Director WOODLAND HILLS REGION 1: ...
# Encrypted total votes for WRITE-IN in School Director WOODLAND HILLS REGION 1: ...
# Encrypted total votes for Andre D. Moore in School Director WOODLAND HILLS REGION 1: ...
# Encrypted total votes for Ava Johnson in School Director WOODLAND HILLS REGION 2: ...
# Encrypted total votes for James W. Weems, Jr. in School Director WOODLAND HILLS REGION 2: ...
# Encrypted total votes for Jeff Hanchett in School Director WOODLAND HILLS REGION 2: ...
# Encrypted total votes for WRITE-IN in School Director WOODLAND HILLS REGION 2: ...
# Encrypted total votes for Jamie L. Glasser in School Director WOODLAND HILLS REGION 3: ...
# Encrypted total votes for WRITE-IN in School Director WOODLAND HILLS REGION 3: ...
# Encrypted total votes for Donna L. Snyder in Supervisor At-Large RICHLAND: ...
# Encrypted total votes for WRITE-IN in Supervisor At-Large RICHLAND: ...
# Encrypted total votes for WRITE-IN in Supervisor FAWN: ...
# Encrypted total votes for Jason Davidek in Supervisor FAWN: ...
# Encrypted total votes for David A. Montanari in Supervisor FAWN: ...
# Encrypted total votes for WRITE-IN in Supervisor FINDLAY: ...
# Encrypted total votes for Thomas J. Gallant in Supervisor FINDLAY: ...
# Encrypted total votes for WRITE-IN in Supervisor FORWARD: ...
# Encrypted total votes for William J. Creevey in Supervisor FRAZER: ...
# Encrypted total votes for WRITE-IN in Supervisor FRAZER: ...
# Encrypted total votes for Jerry R. Chalmers in Supervisor HARMAR: ...
# Encrypted total votes for WRITE-IN in Supervisor HARMAR: ...
# Encrypted total votes for Paula M. Hiteshew in Supervisor HARMAR: ...
# Encrypted total votes for WRITE-IN in Supervisor INDIANA DISTRICT 1: ...
# Encrypted total votes for Albert Fredrik Kaan in Supervisor INDIANA DISTRICT 2: ...
# Encrypted total votes for WRITE-IN in Supervisor INDIANA DISTRICT 2: ...
# Encrypted total votes for Darrin J. Krally in Supervisor INDIANA DISTRICT 3: ...
# Encrypted total votes for WRITE-IN in Supervisor INDIANA DISTRICT 3: ...
# Encrypted total votes for Daniel L. Taylor in Supervisor INDIANA DISTRICT 4: ...
# Encrypted total votes for WRITE-IN in Supervisor INDIANA DISTRICT 4: ...
# Encrypted total votes for WRITE-IN in Supervisor KILBUCK: ...
# Encrypted total votes for Thomas J. Madigan in Supervisor MARSHALL: ...
# Encrypted total votes for WRITE-IN in Supervisor MARSHALL: ...
# Encrypted total votes for WRITE-IN in Supervisor MOON: ...
# Encrypted total votes for Marvin D. Eicher in Supervisor MOON: ...
# Encrypted total votes for WRITE-IN in Supervisor NORTH FAYETTE: ...
# Encrypted total votes for WRITE-IN in Supervisor OHIO: ...
# Encrypted total votes for Frank J. Spagnolo in Supervisor PINE: ...
# Encrypted total votes for Philip D. Henry in Supervisor PINE: ...
# Encrypted total votes for Pasquale Avolio in Supervisor PINE: ...
# Encrypted total votes for WRITE-IN in Supervisor PINE: ...
# Encrypted total votes for WRITE-IN in Supervisor RICHLAND SUPERVISOR 3: ...
# Encrypted total votes for George P. Allen in Supervisor RICHLAND SUPERVISOR 3: ...
# Encrypted total votes for WRITE-IN in Supervisor RICHLAND SUPERVISOR 4: ...
# Encrypted total votes for Raymond P. Kendrick in Supervisor RICHLAND SUPERVISOR 4: ...
# Encrypted total votes for Edward Snee in Supervisor SOUTH PARK: ...
# Encrypted total votes for WRITE-IN in Supervisor SOUTH PARK: ...
# Encrypted total votes for Joyce A. Romig in Supervisor WEST DEER: ...
# Encrypted total votes for James M. Cesnick in Supervisor WEST DEER: ...
# Encrypted total votes for Shirley Hollibaugh in Supervisor WEST DEER: ...
# Encrypted total votes for WRITE-IN in Supervisor WEST DEER: ...
# Encrypted total votes for Lawrence K. McManus in Supervisor WEST DEER: ...
# Encrypted total votes for Don Simonetti in Supervisor WEST DEER: ...
# Encrypted total votes for WRITE-IN in TAX COLLECTOR CORAOPOLIS: ...
# Encrypted total votes for WRITE-IN in TAX COLLECTOR FAWN: ...
# Encrypted total votes for WRITE-IN in TAX COLLECTOR HAYSVILLE: ...
# Encrypted total votes for WRITE-IN in TAX COLLECTOR KILBUCK: ...
# Encrypted total votes for WRITE-IN in TAX COLLECTOR MT OLIVER: ...
# Encrypted total votes for WRITE-IN in TAX COLLECTOR NEVILLE: ...
# Encrypted total votes for WRITE-IN in TAX COLLECTOR OAKMONT: ...
# Encrypted total votes for WRITE-IN in TAX COLLECTOR SEWICKLEY: ...
# Encrypted total votes for Kathryn Winwood in TAX COLLECTOR SPRINGDALE TOWNSHIP: ...
# Encrypted total votes for WRITE-IN in TAX COLLECTOR SPRINGDALE TOWNSHIP: ...
# Encrypted total votes for WRITE-IN in TAX COLLECTOR THORNBURG: ...
# Encrypted total votes for David J. Bires in Treasurer DUQUESNE: ...
# Encrypted total votes for WRITE-IN in Treasurer DUQUESNE: ...
# Encrypted total votes for WRITE-IN in Treasurer MT LEBANON: ...
# Encrypted total votes for Yes in Wilkinsburg Question: ...
# Encrypted total votes for No in Wilkinsburg Question: ...
